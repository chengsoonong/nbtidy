# %% [markdown]
# # Toy process C
#
# Compute the mean of each column, and plot a histogram.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
common = pd.read_csv('common.csv')
average = common.mean()
average
# Out:
# A    8.540177e-18
# B   -2.348549e-17
# C   -3.843080e-17
# D    6.966103e-01
# E    6.123337e-01
# F    4.405637e-01
# G    4.089758e-01
# H    5.457184e-01
# dtype: float64

# %%
average.to_csv('average.csv')

# %%
plt.plot(common)
plt.savefig('toy_hist.pdf')
